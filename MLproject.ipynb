# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import re
import string

# print("all are install")

# %%
Fakedata=pd.read_csv('Fake.csv')
Truedata=pd.read_csv('True.csv')

# %%
# we will insert column just as a target fiture
Fakedata['class']=0
Truedata['class']=1
# Out:
# ((23481, 5), (21417, 5))

# %%
Fakedata.shape,Truedata.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
Fakedata_manual_testing=pd.read_csv('Fake.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 akedata_manual_testing = Fakedata.tail(10)
#       3 for i in range(23481, 23470, -1):
# ----> 4     Fakedata.drop(i, inplace=True)
#
# File ~\PycharmProjects\pythonProject\.venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
# ...
